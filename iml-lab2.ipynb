# %%
#name:rathod dhruvi rajubhai
#enrollment no:216270307090
#Practical No.2: Write a NumPy program to implement following operatio
#to convert a list of numeric values into a one-dimensional NumPy array
import numpy as np
a = np.array([1,2,3,4])
print(a)

# %%
#name:rathod dhruvi rajubhai
#enrollment no:216270307090
#Practical No.2: Write a NumPy program to implement following operatio
#to create a 3x3 matrix with values ranging from 2 to 10
import numpy as np
a = np.array([[[4,4,4],[5,5,5],[2,3,4]]])
print(a)

# %%
#name:rathod dhruvi rajubhai
#enrollment no:216270307090
#Practical No.2: Write a NumPy program to implement following operatio
#to append values at the end of an array
import numpy as np
a=np.array([1,2,3,4,5,6])
b = np.append(a,7)
print(b)

# %%
#name:rathod dhruvi rajubhai
#enrollment no:216270307090
#Practical No.2: Write a NumPy program to implement following operatio
#to create another shape from an array without changing its data (3*2 to 2*3) 
a= np.array([4,6,5,4,5,6])
print("original a:", a)

b = a.reshape(3,2)
print("new b of shape 3*2:\n",b)

b = a.reshape(2,3)
print("new b of shape 2*3:\n",b)
